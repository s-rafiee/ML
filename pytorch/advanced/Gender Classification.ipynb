# %%
import numpy as np
import glob
import torch
from PIL import Image
from torch.utils.data import DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# torch.manual_seed(17)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "CPU")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Data Loader

# %%
class Gender_Dataset(torch.utils.data.Dataset):
    
    def __init__(self, root, transforms=None, target_transforms= None):
        super(Gender_Dataset, self).__init__()
        self.transforms = transforms
        self.target_transforms = target_transforms
        
        # Read Male Data 
        urls = glob.glob(root + '/male/*.jpg')
        labels = np.zeros(len(urls))
        self.urls = urls
        self.targets = labels
        
        # Read Famale Data 
        urls = glob.glob(root + '/female/*.jpg')
        labels = np.ones(len(urls))
        self.urls = self.urls + urls
        self.targets = np.array(list(self.targets) + list(labels), int) # also convert to int
    
    def __len__(self):
        return len(self.urls)
    
    def __getitem__(self, idx):
        image = Image.open(self.urls[idx]).convert("RGB")
        label = self.targets[idx]
        
        image = image.resize((200,200))
        
        if self.transforms:
            image = self.transforms(image)
        
        if self.target_transforms:
            label = self.target_transforms(label)
        
        image = np.array(image)/255.0
        image = image.reshape((3,200,200))
        return image, label

# %%
 
data_dir = {"train":"Datasets/Gender_Classification/Train", "test":"Datasets/Gender_Classification/Test"}

train_transform = transforms.Compose([transforms.RandomRotation(45),
#                                       transforms.Resize((200,200))
                                     ])
test_transform = transforms.Compose([transforms.RandomRotation(45),
#                                       transforms.Resize((200,200))
                                     ])
train_data = Gender_Dataset(root=data_dir['train'], transforms=train_transform)
test_data = Gender_Dataset(root=data_dir['test'], transforms=test_transform)

batch_size = 64
train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Show Sample Data

# %%
example_data = next(iter(train_dataloader))
images = np.array(example_data[0])
labels = np.array(example_data[1])
fig = plt.figure()
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.tight_layout()
    plt.imshow(images[i].reshape(200, 200, 3), cmap='gray', interpolation='none')
    plt.title('Gender is: {}'.format("male" if np.argmax(labels[i]) == 0 else "female"))
    plt.xticks([])
    plt.yticks([])

# %%
class Gender(nn.Module):
    
    def __init__(self):
        super(Gender, self).__init__()
        self.number_class = 1
        self.lr = 0.001
        
        self.conv1 = nn.Conv2d(3, 20, kernel_size=3)
        self.BN1 = nn.BatchNorm2d(20,20)
        self.conv2 = nn.Conv2d(20, 40, kernel_size=3)
        self.BN2 = nn.BatchNorm2d(40,40)
        self.conv3 = nn.Conv2d(40, 60, kernel_size=3)
        self.BN3 = nn.BatchNorm2d(60,60)
        self.conv4 = nn.Conv2d(60, 128, kernel_size=3)
        self.BN4 = nn.BatchNorm2d(128,128)
        self.fc1 = nn.Linear(128*10*10, 64)
        self.BN5 = nn.BatchNorm2d(128*10*10,128*10*10)
        self.fc2 = nn.Linear(64, 32)
        self.BN6 = nn.BatchNorm2d(32,32)
        self.fc3 = nn.Linear(32, 2)
        self.softMax = nn.LogSoftmax(dim=1)
        
    
    def forward(self, X):
        # Layer 1 
        X = self.conv1(X)
        X = F.max_pool2d(X, kernel_size=2)
        X = F.relu(X)
#         X = self.BN1(X)
        
        # Layer 2
        X = self.conv2(X)
        X = F.max_pool2d(X, kernel_size=2)
        X = F.relu(X)
#         X = self.BN2(X)
        
        # Layer 3
        X = self.conv3(X)
        X = F.max_pool2d(X, kernel_size=2)
        X = F.relu(X)
#         X = self.BN3(X)
        
        # Layer 4
        X = self.conv4(X)
        X = F.max_pool2d(X, kernel_size=2)
        X = F.relu(X)
#         X = self.BN4(X)
        
        # Convert to Vector
        X = X.view(X.size(0), -1)
        
        X = self.fc1(X)
        X = nn.Dropout(p=0.2)(X)
        X = F.relu(X)
#         X = self.BN5(X)
        
        X = self.fc2(X)
        X = nn.Dropout(p=0.2)(X)
        X = F.relu(X)
#         X = self.BN6(X)
        
        X = self.fc3(X)
        X = self.softMax(X)
        
        return X

def binary_acc(y_pred, y_test):
    y_pred_tag = torch.round(torch.softmax(y_pred, dim=1))

    correct_results_sum = (y_pred_tag == y_test).sum().float()
    acc = correct_results_sum/y_test.shape[0]
    acc = torch.round(acc * 100)
    
    return acc

def train_model(dataloader, epochs=0, verbos=False):
    steps = 0
    epoch_loss= []

    for epoch in range(epochs):
        model.train()
        loss_list = []
#         i=0
        for batch_index, (data, target) in enumerate(dataloader):
            data, target = data.to('cuda'), target.to('cuda')
#             print(target.unsqueeze(1))
            steps += 1
#             model.n
            optimizer.zero_grad()
            output = model(data.float())
            loss = loss_function(output, target)
#             acc = binary_acc(output, target.unsqueeze(1))
            acc = 0
            loss.backward()
            optimizer.step()
            loss_list.append(loss.item())
            if verbos:
                print("Epoch {}/{}  batch {}, train Error :{}, Train Acc:{}".format(epoch+1,
                                                                                  epochs,
                                                                                  batch_index+1,
                                                                                  loss,
                                                                                   acc))
#             i+=1
#             if i>10:
#                 break
        epoch_loss.append(loss_list)
    return epoch_loss
#                 model(data.float())
#                 print(data.shape)

    
model = Gender()
model.to(device)
# optimizer = optim.Adam(model.parameters(), lr=0.03)
# loss_function = nn.MSELoss()
loss_function = nn.NLLLoss()
learning_rate = 0.003
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

error_lists = train_model(train_dataloader, epochs=3, verbos=True)
plt.plot(np.mean(error_lists, axis=0))

# for parameter in model.parameters():
#     print(parameter[0])
# Out:
# Epoch 1/3  batch 1, train Error :0.6927401423454285, Train Acc:0
# Epoch 1/3  batch 2, train Error :0.6772898435592651, Train Acc:0
# Epoch 1/3  batch 3, train Error :0.8346205353736877, Train Acc:0
# Epoch 1/3  batch 4, train Error :0.7316617369651794, Train Acc:0
# Epoch 1/3  batch 5, train Error :0.695199728012085, Train Acc:0
# Epoch 1/3  batch 6, train Error :0.698622465133667, Train Acc:0
# Epoch 1/3  batch 7, train Error :0.6891176700592041, Train Acc:0
# Epoch 1/3  batch 8, train Error :0.6855767965316772, Train Acc:0
# Epoch 1/3  batch 9, train Error :0.6771215200424194, Train Acc:0
# Epoch 1/3  batch 10, train Error :0.797888457775116, Train Acc:0
# Epoch 1/3  batch 11, train Error :0.6934359073638916, Train Acc:0
# Epoch 1/3  batch 12, train Error :0.688591480255127, Train Acc:0
# Epoch 1/3  batch 13, train Error :0.6914918422698975, Train Acc:0
# Epoch 1/3  batch 14, train Error :0.69285649061203, Train Acc:0
# Epoch 1/3  batch 15, train Error :0.6941443681716919, Train Acc:0
# Epoch 1/3  batch 16, train Error :0.6907115578651428, Train Acc:0
# Epoch 1/3  batch 17, train Error :0.6892273426055908, Train Acc:0
# Epoch 1/3  batch 18, train Error :0.6975168585777283, Train Acc:0
# Epoch 1/3  batch 19, train Error :0.6946970820426941, Train Acc:0
# Epoch 1/3  batch 20, train Error :0.6979789137840271, Train Acc:0
# Epoch 1/3  batch 21, train Error :0.6931619048118591, Train Acc:0
# Epoch 1/3  batch 22, train Error :0.6957469582557678, Train Acc:0
# Epoch 1/3  batch 23, train Error :0.6956009268760681, Train Acc:0
# Epoch 1/3  batch 24, train Error :0.6927904486656189, Train Acc:0
# Epoch 1/3  batch 25, train Error :0.6948679685592651, Train Acc:0
# Epoch 1/3  batch 26, train Error :0.6943621039390564, Train Acc:0
# Epoch 1/3  batch 27, train Error :0.6929270625114441, Train Acc:0
# Epoch 1/3  batch 28, train Error :0.690808117389679, Train Acc:0
# Epoch 1/3  batch 29, train Error :0.6921259760856628, Train Acc:0
# Epoch 1/3  batch 30, train Error :0.6933472156524658, Train Acc:0
# Epoch 1/3  batch 31, train Error :0.69301438331604, Train Acc:0
# Epoch 1/3  batch 32, train Error :0.6967876553535461, Train Acc:0
# Epoch 1/3  batch 33, train Error :0.6957246661186218, Train Acc:0
# Epoch 1/3  batch 34, train Error :0.6958521008491516, Train Acc:0
# Epoch 1/3  batch 35, train Error :0.6922507882118225, Train Acc:0
# Epoch 1/3  batch 36, train Error :0.6925005912780762, Train Acc:0
# Epoch 1/3  batch 37, train Error :0.6929898262023926, Train Acc:0
# Epoch 1/3  batch 38, train Error :0.6934973001480103, Train Acc:0
# Epoch 1/3  batch 39, train Error :0.689013659954071, Train Acc:0
# Epoch 1/3  batch 40, train Error :0.692545473575592, Train Acc:0
# Epoch 1/3  batch 41, train Error :0.696169376373291, Train Acc:0
# Epoch 1/3  batch 42, train Error :0.6979414224624634, Train Acc:0
# Epoch 1/3  batch 43, train Error :0.6974998712539673, Train Acc:0
# Epoch 1/3  batch 44, train Error :0.6967440843582153, Train Acc:0
# Epoch 1/3  batch 45, train Error :0.6960580348968506, Train Acc:0
# Epoch 1/3  batch 46, train Error :0.694272518157959, Train Acc:0
# Epoch 1/3  batch 47, train Error :0.6900501251220703, Train Acc:0
# Epoch 1/3  batch 48, train Error :0.6988176107406616, Train Acc:0
# Epoch 1/3  batch 49, train Error :0.6908846497535706, Train Acc:0
# Epoch 1/3  batch 50, train Error :0.6938036680221558, Train Acc:0
# Epoch 1/3  batch 51, train Error :0.6969377994537354, Train Acc:0
# Epoch 1/3  batch 52, train Error :0.6956618428230286, Train Acc:0
# Epoch 1/3  batch 53, train Error :0.6935915946960449, Train Acc:0
# Epoch 1/3  batch 54, train Error :0.69074946641922, Train Acc:0
# Epoch 1/3  batch 55, train Error :0.6925787329673767, Train Acc:0
# Epoch 1/3  batch 56, train Error :0.6931082606315613, Train Acc:0
# Epoch 1/3  batch 57, train Error :0.6926219463348389, Train Acc:0
# Epoch 1/3  batch 58, train Error :0.6944072842597961, Train Acc:0
# Epoch 1/3  batch 59, train Error :0.6916835308074951, Train Acc:0
# Epoch 1/3  batch 60, train Error :0.6908710598945618, Train Acc:0
# Epoch 1/3  batch 61, train Error :0.6945488452911377, Train Acc:0
# Epoch 1/3  batch 62, train Error :0.6927536725997925, Train Acc:0
# Epoch 1/3  batch 63, train Error :0.693324863910675, Train Acc:0
# Epoch 1/3  batch 64, train Error :0.6925106644630432, Train Acc:0
# Epoch 1/3  batch 65, train Error :0.698482096195221, Train Acc:0
# Epoch 1/3  batch 66, train Error :0.6972972750663757, Train Acc:0
# Epoch 1/3  batch 67, train Error :0.6978964805603027, Train Acc:0
# Epoch 1/3  batch 68, train Error :0.6919547915458679, Train Acc:0
# Epoch 1/3  batch 69, train Error :0.6941902041435242, Train Acc:0
# Epoch 1/3  batch 70, train Error :0.6936714053153992, Train Acc:0
# Epoch 1/3  batch 71, train Error :0.6947674751281738, Train Acc:0
# Epoch 1/3  batch 72, train Error :0.6934506893157959, Train Acc:0
# Epoch 1/3  batch 73, train Error :0.6952916979789734, Train Acc:0
# Epoch 1/3  batch 74, train Error :0.6926047205924988, Train Acc:0
# Epoch 1/3  batch 75, train Error :0.693284809589386, Train Acc:0
# Epoch 1/3  batch 76, train Error :0.6937331557273865, Train Acc:0
# Epoch 1/3  batch 77, train Error :0.6928979158401489, Train Acc:0
# Epoch 1/3  batch 78, train Error :0.6921716928482056, Train Acc:0
# Epoch 1/3  batch 79, train Error :0.6941841840744019, Train Acc:0
# Epoch 1/3  batch 80, train Error :0.6934393644332886, Train Acc:0
# Epoch 1/3  batch 81, train Error :0.6937121748924255, Train Acc:0
# Epoch 1/3  batch 82, train Error :0.6927651762962341, Train Acc:0
# Epoch 1/3  batch 83, train Error :0.6921651363372803, Train Acc:0
# Epoch 1/3  batch 84, train Error :0.6930277943611145, Train Acc:0
# Epoch 1/3  batch 85, train Error :0.6941062211990356, Train Acc:0
# Epoch 1/3  batch 86, train Error :0.6921828985214233, Train Acc:0
# Epoch 1/3  batch 87, train Error :0.6944561004638672, Train Acc:0
# Epoch 1/3  batch 88, train Error :0.6925767660140991, Train Acc:0
# Epoch 1/3  batch 89, train Error :0.6923513412475586, Train Acc:0
# Epoch 1/3  batch 90, train Error :0.6941739916801453, Train Acc:0
# Epoch 1/3  batch 91, train Error :0.6920477151870728, Train Acc:0
# Epoch 1/3  batch 92, train Error :0.6957643032073975, Train Acc:0
# Epoch 1/3  batch 93, train Error :0.6924049854278564, Train Acc:0
# Epoch 1/3  batch 94, train Error :0.6905548572540283, Train Acc:0
# Epoch 1/3  batch 95, train Error :0.6916693449020386, Train Acc:0
# Epoch 1/3  batch 96, train Error :0.6926141977310181, Train Acc:0
# Epoch 1/3  batch 97, train Error :0.6939082145690918, Train Acc:0
# Epoch 1/3  batch 98, train Error :0.6893990635871887, Train Acc:0
# Epoch 1/3  batch 99, train Error :0.7008155584335327, Train Acc:0
# Epoch 1/3  batch 100, train Error :0.6887836456298828, Train Acc:0
# Epoch 1/3  batch 101, train Error :0.6889391541481018, Train Acc:0
# Epoch 1/3  batch 102, train Error :0.6953675746917725, Train Acc:0
# Epoch 1/3  batch 103, train Error :0.6925954222679138, Train Acc:0
# Epoch 1/3  batch 104, train Error :0.6898186802864075, Train Acc:0
# Epoch 1/3  batch 105, train Error :0.694101870059967, Train Acc:0
# Epoch 1/3  batch 106, train Error :0.693142831325531, Train Acc:0
# Epoch 1/3  batch 107, train Error :0.6978415846824646, Train Acc:0
# Epoch 1/3  batch 108, train Error :0.69707190990448, Train Acc:0
# Epoch 1/3  batch 109, train Error :0.6928591728210449, Train Acc:0
# Epoch 1/3  batch 110, train Error :0.6950197815895081, Train Acc:0
# Epoch 1/3  batch 111, train Error :0.6943618655204773, Train Acc:0
# Epoch 1/3  batch 112, train Error :0.6925925612449646, Train Acc:0
# Epoch 1/3  batch 113, train Error :0.6929560899734497, Train Acc:0
# Epoch 1/3  batch 114, train Error :0.6925283074378967, Train Acc:0
# Epoch 1/3  batch 115, train Error :0.6929612755775452, Train Acc:0
# Epoch 1/3  batch 116, train Error :0.6957569122314453, Train Acc:0
# Epoch 1/3  batch 117, train Error :0.6925555467605591, Train Acc:0
# Epoch 1/3  batch 118, train Error :0.6917657256126404, Train Acc:0
# Epoch 1/3  batch 119, train Error :0.6928694844245911, Train Acc:0
# Epoch 1/3  batch 120, train Error :0.6909546852111816, Train Acc:0
# Epoch 1/3  batch 121, train Error :0.6927530765533447, Train Acc:0
# Epoch 1/3  batch 122, train Error :0.6914516687393188, Train Acc:0
# Epoch 1/3  batch 123, train Error :0.691758394241333, Train Acc:0
# Epoch 1/3  batch 124, train Error :0.6926358342170715, Train Acc:0
# Epoch 1/3  batch 125, train Error :0.6908286213874817, Train Acc:0
# Epoch 1/3  batch 126, train Error :0.6906006932258606, Train Acc:0
# Epoch 1/3  batch 127, train Error :0.6892945766448975, Train Acc:0
# Epoch 1/3  batch 128, train Error :0.6944666504859924, Train Acc:0
# Epoch 1/3  batch 129, train Error :0.6899715065956116, Train Acc:0
# Epoch 1/3  batch 130, train Error :0.6896927356719971, Train Acc:0
# Epoch 1/3  batch 131, train Error :0.6879423260688782, Train Acc:0
# Epoch 1/3  batch 132, train Error :0.6899224519729614, Train Acc:0
# Epoch 1/3  batch 133, train Error :0.6840566396713257, Train Acc:0
# Epoch 1/3  batch 134, train Error :0.7007172703742981, Train Acc:0
# Epoch 1/3  batch 135, train Error :0.6914381980895996, Train Acc:0
# Epoch 1/3  batch 136, train Error :0.6864312291145325, Train Acc:0
# Epoch 1/3  batch 137, train Error :0.6970645785331726, Train Acc:0
# Epoch 1/3  batch 138, train Error :0.7011384963989258, Train Acc:0
# Epoch 1/3  batch 139, train Error :0.6837671995162964, Train Acc:0
# Epoch 1/3  batch 140, train Error :0.689099907875061, Train Acc:0
# Epoch 1/3  batch 141, train Error :0.7068477272987366, Train Acc:0
# Epoch 1/3  batch 142, train Error :0.6849868893623352, Train Acc:0
# Epoch 1/3  batch 143, train Error :0.684070348739624, Train Acc:0
# Epoch 1/3  batch 144, train Error :0.6750439405441284, Train Acc:0
# Epoch 1/3  batch 145, train Error :0.683264434337616, Train Acc:0
# Epoch 1/3  batch 146, train Error :0.6741282939910889, Train Acc:0
# Epoch 1/3  batch 147, train Error :0.6899153590202332, Train Acc:0
# Epoch 1/3  batch 148, train Error :0.6698870658874512, Train Acc:0
# Epoch 1/3  batch 149, train Error :0.683563768863678, Train Acc:0
# Epoch 1/3  batch 150, train Error :0.7421938180923462, Train Acc:0
# Epoch 1/3  batch 151, train Error :0.6791437864303589, Train Acc:0
# Epoch 1/3  batch 152, train Error :0.6635162234306335, Train Acc:0
# Epoch 1/3  batch 153, train Error :0.6547931432723999, Train Acc:0
# Epoch 1/3  batch 154, train Error :0.668150782585144, Train Acc:0
# Epoch 1/3  batch 155, train Error :0.635390043258667, Train Acc:0
# Epoch 1/3  batch 156, train Error :0.6624558568000793, Train Acc:0
# Epoch 1/3  batch 157, train Error :0.664036214351654, Train Acc:0
# Epoch 1/3  batch 158, train Error :0.6703131198883057, Train Acc:0
# Epoch 1/3  batch 159, train Error :0.6619025468826294, Train Acc:0
# Epoch 1/3  batch 160, train Error :0.6697225570678711, Train Acc:0
# Epoch 1/3  batch 161, train Error :0.6311052441596985, Train Acc:0
# Epoch 1/3  batch 162, train Error :0.7280440926551819, Train Acc:0
# Epoch 1/3  batch 163, train Error :0.6065405607223511, Train Acc:0
# Epoch 1/3  batch 164, train Error :0.7066777944564819, Train Acc:0
# Epoch 1/3  batch 165, train Error :0.6512132287025452, Train Acc:0
# Epoch 1/3  batch 166, train Error :0.6860523819923401, Train Acc:0
# Epoch 1/3  batch 167, train Error :0.6896981000900269, Train Acc:0
# Epoch 1/3  batch 168, train Error :0.6749303340911865, Train Acc:0
# Epoch 1/3  batch 169, train Error :0.7078587412834167, Train Acc:0
# Epoch 1/3  batch 170, train Error :0.6724840402603149, Train Acc:0
# Epoch 1/3  batch 171, train Error :0.6943141222000122, Train Acc:0
# Epoch 1/3  batch 172, train Error :0.6767752170562744, Train Acc:0
# Epoch 1/3  batch 173, train Error :0.6869500875473022, Train Acc:0
# Epoch 1/3  batch 174, train Error :0.6643475890159607, Train Acc:0
# Epoch 1/3  batch 175, train Error :0.6791943907737732, Train Acc:0
# Epoch 1/3  batch 176, train Error :0.6739096641540527, Train Acc:0
# Epoch 1/3  batch 177, train Error :0.6757255792617798, Train Acc:0
# Epoch 1/3  batch 178, train Error :0.658636748790741, Train Acc:0
# Epoch 1/3  batch 179, train Error :0.6728018522262573, Train Acc:0
# Epoch 1/3  batch 180, train Error :0.6713826656341553, Train Acc:0
# Epoch 1/3  batch 181, train Error :0.6181066036224365, Train Acc:0
# Epoch 1/3  batch 182, train Error :0.6835376024246216, Train Acc:0
# Epoch 1/3  batch 183, train Error :0.6257473230361938, Train Acc:0
# Epoch 1/3  batch 184, train Error :0.641400158405304, Train Acc:0
# Epoch 1/3  batch 185, train Error :0.68727707862854, Train Acc:0
# Epoch 1/3  batch 186, train Error :0.6184067130088806, Train Acc:0
# Epoch 1/3  batch 187, train Error :0.6637798547744751, Train Acc:0
# Epoch 1/3  batch 188, train Error :0.6014128923416138, Train Acc:0
# Epoch 1/3  batch 189, train Error :0.6890489459037781, Train Acc:0
# Epoch 1/3  batch 190, train Error :0.6646230816841125, Train Acc:0
# Epoch 1/3  batch 191, train Error :0.6472878456115723, Train Acc:0
# Epoch 1/3  batch 192, train Error :0.6576104164123535, Train Acc:0
# Epoch 1/3  batch 193, train Error :0.6814510822296143, Train Acc:0
# Epoch 1/3  batch 194, train Error :0.6510366797447205, Train Acc:0
# Epoch 1/3  batch 195, train Error :0.6668396592140198, Train Acc:0
# Epoch 1/3  batch 196, train Error :0.6541025042533875, Train Acc:0
# Epoch 1/3  batch 197, train Error :0.7227285504341125, Train Acc:0
# Epoch 1/3  batch 198, train Error :0.7138398885726929, Train Acc:0
# Epoch 1/3  batch 199, train Error :0.6857150197029114, Train Acc:0
# Epoch 1/3  batch 200, train Error :0.6760061979293823, Train Acc:0
# Epoch 1/3  batch 201, train Error :0.6868383884429932, Train Acc:0
# Epoch 1/3  batch 202, train Error :0.6763640642166138, Train Acc:0
# Epoch 1/3  batch 203, train Error :0.6612133383750916, Train Acc:0
# Epoch 1/3  batch 204, train Error :0.6923097968101501, Train Acc:0
# Epoch 1/3  batch 205, train Error :0.6676465272903442, Train Acc:0
# Epoch 1/3  batch 206, train Error :0.6818141937255859, Train Acc:0
# Epoch 1/3  batch 207, train Error :0.6578935980796814, Train Acc:0
# Epoch 1/3  batch 208, train Error :0.6445788741111755, Train Acc:0
# Epoch 1/3  batch 209, train Error :0.6578515768051147, Train Acc:0
# Epoch 1/3  batch 210, train Error :0.6514158248901367, Train Acc:0
# Epoch 1/3  batch 211, train Error :0.6317787170410156, Train Acc:0
# Epoch 1/3  batch 212, train Error :0.6185212135314941, Train Acc:0
# Epoch 1/3  batch 213, train Error :0.7143605947494507, Train Acc:0
# Epoch 1/3  batch 214, train Error :0.6945745348930359, Train Acc:0
# Epoch 1/3  batch 215, train Error :0.6545706987380981, Train Acc:0
# Epoch 1/3  batch 216, train Error :0.5899400115013123, Train Acc:0
# Epoch 1/3  batch 217, train Error :0.6011528968811035, Train Acc:0
# Epoch 1/3  batch 218, train Error :0.6104723811149597, Train Acc:0
# Epoch 1/3  batch 219, train Error :0.6317020654678345, Train Acc:0
# Epoch 1/3  batch 220, train Error :0.6382339000701904, Train Acc:0
# Epoch 1/3  batch 221, train Error :0.5871382355690002, Train Acc:0
# Epoch 1/3  batch 222, train Error :0.6360741853713989, Train Acc:0
# Epoch 1/3  batch 223, train Error :0.6638519763946533, Train Acc:0
# Epoch 1/3  batch 224, train Error :0.652923047542572, Train Acc:0
# Epoch 1/3  batch 225, train Error :0.6385710835456848, Train Acc:0
# Epoch 1/3  batch 226, train Error :0.6808767318725586, Train Acc:0
# Epoch 1/3  batch 227, train Error :0.6451226472854614, Train Acc:0
# Epoch 1/3  batch 228, train Error :0.6125811338424683, Train Acc:0
# Epoch 1/3  batch 229, train Error :0.5955756306648254, Train Acc:0
# Epoch 1/3  batch 230, train Error :0.5975691676139832, Train Acc:0
# Epoch 1/3  batch 231, train Error :0.6124337911605835, Train Acc:0
# Epoch 1/3  batch 232, train Error :0.6188187599182129, Train Acc:0
# Epoch 1/3  batch 233, train Error :0.5877576470375061, Train Acc:0
# Epoch 1/3  batch 234, train Error :0.6138030290603638, Train Acc:0
# Epoch 1/3  batch 235, train Error :0.5380819439888, Train Acc:0
# Epoch 1/3  batch 236, train Error :0.6156519055366516, Train Acc:0
# Epoch 1/3  batch 237, train Error :0.6786469221115112, Train Acc:0
# Epoch 1/3  batch 238, train Error :0.647020697593689, Train Acc:0
# Epoch 1/3  batch 239, train Error :0.5703995823860168, Train Acc:0
# Epoch 1/3  batch 240, train Error :0.667461097240448, Train Acc:0
# Epoch 1/3  batch 241, train Error :0.5769570469856262, Train Acc:0
# Epoch 1/3  batch 242, train Error :0.7077130675315857, Train Acc:0
# Epoch 1/3  batch 243, train Error :0.7572528123855591, Train Acc:0
# Epoch 1/3  batch 244, train Error :0.6354718804359436, Train Acc:0
# Epoch 1/3  batch 245, train Error :0.7044242024421692, Train Acc:0
# Epoch 1/3  batch 246, train Error :0.6141049861907959, Train Acc:0
# Epoch 1/3  batch 247, train Error :0.616070032119751, Train Acc:0
# Epoch 1/3  batch 248, train Error :0.6256258487701416, Train Acc:0
# Epoch 1/3  batch 249, train Error :0.6735531091690063, Train Acc:0
# Epoch 1/3  batch 250, train Error :0.6173850893974304, Train Acc:0
# Epoch 1/3  batch 251, train Error :0.6315547227859497, Train Acc:0
# Epoch 1/3  batch 252, train Error :0.625893235206604, Train Acc:0
# Epoch 1/3  batch 253, train Error :0.6263285279273987, Train Acc:0
# Epoch 1/3  batch 254, train Error :0.6442330479621887, Train Acc:0
# Epoch 1/3  batch 255, train Error :0.6141270399093628, Train Acc:0
# Epoch 1/3  batch 256, train Error :0.6211800575256348, Train Acc:0
# Epoch 1/3  batch 257, train Error :0.6176767945289612, Train Acc:0
# Epoch 1/3  batch 258, train Error :0.6294043660163879, Train Acc:0
# Epoch 1/3  batch 259, train Error :0.6502571702003479, Train Acc:0
# Epoch 1/3  batch 260, train Error :0.6092985272407532, Train Acc:0
# Epoch 1/3  batch 261, train Error :0.709485650062561, Train Acc:0
# Epoch 1/3  batch 262, train Error :0.6098909378051758, Train Acc:0
# Epoch 1/3  batch 263, train Error :0.5546566843986511, Train Acc:0
# Epoch 1/3  batch 264, train Error :0.54920494556427, Train Acc:0
# Epoch 1/3  batch 265, train Error :0.6035275459289551, Train Acc:0
# Epoch 1/3  batch 266, train Error :0.7644774913787842, Train Acc:0
# Epoch 1/3  batch 267, train Error :0.6484545469284058, Train Acc:0
# Epoch 1/3  batch 268, train Error :0.5993697643280029, Train Acc:0
# Epoch 1/3  batch 269, train Error :0.6026288270950317, Train Acc:0
# Epoch 1/3  batch 270, train Error :0.762542188167572, Train Acc:0
# Epoch 1/3  batch 271, train Error :0.6766634583473206, Train Acc:0
# Epoch 1/3  batch 272, train Error :0.6720160245895386, Train Acc:0
# Epoch 1/3  batch 273, train Error :0.5901652574539185, Train Acc:0
# Epoch 1/3  batch 274, train Error :0.6718043684959412, Train Acc:0
# Epoch 1/3  batch 275, train Error :0.652055025100708, Train Acc:0
# Epoch 1/3  batch 276, train Error :0.660307765007019, Train Acc:0
# Epoch 1/3  batch 277, train Error :0.6877191066741943, Train Acc:0
# Epoch 1/3  batch 278, train Error :0.6827048063278198, Train Acc:0
# Epoch 1/3  batch 279, train Error :0.6596329808235168, Train Acc:0
# Epoch 1/3  batch 280, train Error :0.644330620765686, Train Acc:0
# Epoch 1/3  batch 281, train Error :0.6633254885673523, Train Acc:0
# Epoch 1/3  batch 282, train Error :0.676471471786499, Train Acc:0
# Epoch 1/3  batch 283, train Error :0.6519924402236938, Train Acc:0
# Epoch 1/3  batch 284, train Error :0.6555253863334656, Train Acc:0
# Epoch 1/3  batch 285, train Error :0.699038028717041, Train Acc:0
# Epoch 1/3  batch 286, train Error :0.6696363091468811, Train Acc:0
# Epoch 1/3  batch 287, train Error :0.6309090256690979, Train Acc:0
# Epoch 1/3  batch 288, train Error :0.6611528396606445, Train Acc:0
# Epoch 1/3  batch 289, train Error :0.655588686466217, Train Acc:0
# Epoch 1/3  batch 290, train Error :0.6139514446258545, Train Acc:0
# Epoch 1/3  batch 291, train Error :0.655817985534668, Train Acc:0
# Epoch 1/3  batch 292, train Error :0.62391597032547, Train Acc:0
# Epoch 1/3  batch 293, train Error :0.6536980271339417, Train Acc:0
# Epoch 1/3  batch 294, train Error :0.6732699275016785, Train Acc:0
# Epoch 1/3  batch 295, train Error :0.6113556623458862, Train Acc:0
# Epoch 1/3  batch 296, train Error :0.6764882206916809, Train Acc:0
# Epoch 1/3  batch 297, train Error :0.636422336101532, Train Acc:0
# Epoch 1/3  batch 298, train Error :0.5995090007781982, Train Acc:0
# Epoch 1/3  batch 299, train Error :0.6551904678344727, Train Acc:0
# Epoch 1/3  batch 300, train Error :0.6325256824493408, Train Acc:0
# Epoch 1/3  batch 301, train Error :0.6599675416946411, Train Acc:0
# Epoch 1/3  batch 302, train Error :0.5326557159423828, Train Acc:0
# Epoch 1/3  batch 303, train Error :0.629787802696228, Train Acc:0
# Epoch 1/3  batch 304, train Error :0.7317925095558167, Train Acc:0
# Epoch 1/3  batch 305, train Error :0.6023447513580322, Train Acc:0
# Epoch 1/3  batch 306, train Error :0.6613867282867432, Train Acc:0
# Epoch 1/3  batch 307, train Error :0.6479488611221313, Train Acc:0
# Epoch 1/3  batch 308, train Error :0.6480148434638977, Train Acc:0
# Epoch 1/3  batch 309, train Error :0.6431873440742493, Train Acc:0
# Epoch 1/3  batch 310, train Error :0.62288498878479, Train Acc:0
# Epoch 1/3  batch 311, train Error :0.637775719165802, Train Acc:0
# Epoch 1/3  batch 312, train Error :0.601891040802002, Train Acc:0
# Epoch 1/3  batch 313, train Error :0.6055092811584473, Train Acc:0
# Epoch 1/3  batch 314, train Error :0.6679891347885132, Train Acc:0
# Epoch 1/3  batch 315, train Error :0.6501693725585938, Train Acc:0
# Epoch 1/3  batch 316, train Error :0.6121065020561218, Train Acc:0
# Epoch 1/3  batch 317, train Error :0.6600447297096252, Train Acc:0
# Epoch 1/3  batch 318, train Error :0.6268805861473083, Train Acc:0
# Epoch 1/3  batch 319, train Error :0.586033046245575, Train Acc:0
# Epoch 1/3  batch 320, train Error :0.6550294756889343, Train Acc:0
# Epoch 1/3  batch 321, train Error :0.6085618138313293, Train Acc:0
# Epoch 1/3  batch 322, train Error :0.6121711134910583, Train Acc:0
# Epoch 1/3  batch 323, train Error :0.6269334554672241, Train Acc:0
# Epoch 1/3  batch 324, train Error :0.643196165561676, Train Acc:0
# Epoch 1/3  batch 325, train Error :0.578299343585968, Train Acc:0
# Epoch 1/3  batch 326, train Error :0.6680606603622437, Train Acc:0
# Epoch 1/3  batch 327, train Error :0.6598696112632751, Train Acc:0
# Epoch 1/3  batch 328, train Error :0.567656934261322, Train Acc:0
# Epoch 1/3  batch 329, train Error :0.6092076897621155, Train Acc:0
# Epoch 1/3  batch 330, train Error :0.6103816628456116, Train Acc:0
# Epoch 1/3  batch 331, train Error :0.5957517623901367, Train Acc:0
# Epoch 1/3  batch 332, train Error :0.6414016485214233, Train Acc:0
# Epoch 1/3  batch 333, train Error :0.6186962127685547, Train Acc:0
# Epoch 1/3  batch 334, train Error :0.6604941487312317, Train Acc:0
# Epoch 1/3  batch 335, train Error :0.6605514883995056, Train Acc:0
# Epoch 1/3  batch 336, train Error :0.676423192024231, Train Acc:0
# Epoch 1/3  batch 337, train Error :0.5805456638336182, Train Acc:0
# Epoch 1/3  batch 338, train Error :0.5963999032974243, Train Acc:0
# Epoch 1/3  batch 339, train Error :0.537043035030365, Train Acc:0
# Epoch 1/3  batch 340, train Error :0.6622334122657776, Train Acc:0
# Epoch 1/3  batch 341, train Error :0.7468760013580322, Train Acc:0
# Epoch 1/3  batch 342, train Error :0.5775529742240906, Train Acc:0
# Epoch 1/3  batch 343, train Error :0.5998659133911133, Train Acc:0
# Epoch 1/3  batch 344, train Error :0.5147457718849182, Train Acc:0
# Epoch 1/3  batch 345, train Error :0.6969226598739624, Train Acc:0
# Epoch 1/3  batch 346, train Error :0.604240357875824, Train Acc:0
# Epoch 1/3  batch 347, train Error :0.644045352935791, Train Acc:0
# Epoch 1/3  batch 348, train Error :0.6622358560562134, Train Acc:0
# Epoch 1/3  batch 349, train Error :0.603643536567688, Train Acc:0
# Epoch 1/3  batch 350, train Error :0.6350322365760803, Train Acc:0
# Epoch 1/3  batch 351, train Error :0.6216685771942139, Train Acc:0
# Epoch 1/3  batch 352, train Error :0.5776906609535217, Train Acc:0
# Epoch 1/3  batch 353, train Error :0.6913266181945801, Train Acc:0
# Epoch 1/3  batch 354, train Error :0.6465224623680115, Train Acc:0
# Epoch 1/3  batch 355, train Error :0.5627127289772034, Train Acc:0
# Epoch 1/3  batch 356, train Error :0.5564773678779602, Train Acc:0
# Epoch 1/3  batch 357, train Error :0.5862147808074951, Train Acc:0
# Epoch 1/3  batch 358, train Error :0.6673957109451294, Train Acc:0
# Epoch 1/3  batch 359, train Error :0.5855728387832642, Train Acc:0
# Epoch 1/3  batch 360, train Error :0.6126130223274231, Train Acc:0
# Epoch 1/3  batch 361, train Error :0.6266822814941406, Train Acc:0
# Epoch 1/3  batch 362, train Error :0.5491635799407959, Train Acc:0
# Epoch 1/3  batch 363, train Error :0.614982008934021, Train Acc:0
# Epoch 1/3  batch 364, train Error :0.5643523335456848, Train Acc:0
# Epoch 1/3  batch 365, train Error :0.574582576751709, Train Acc:0
# Epoch 1/3  batch 366, train Error :0.4910597801208496, Train Acc:0
# Epoch 1/3  batch 367, train Error :0.6310257315635681, Train Acc:0
# Epoch 1/3  batch 368, train Error :0.7036535739898682, Train Acc:0
# Epoch 1/3  batch 369, train Error :0.4973165988922119, Train Acc:0
# Epoch 1/3  batch 370, train Error :0.6816366314888, Train Acc:0
# Epoch 1/3  batch 371, train Error :0.5096815824508667, Train Acc:0
# Epoch 1/3  batch 372, train Error :0.5817297101020813, Train Acc:0
# Epoch 1/3  batch 373, train Error :0.519797682762146, Train Acc:0
# Epoch 1/3  batch 374, train Error :0.5869935154914856, Train Acc:0
# Epoch 1/3  batch 375, train Error :0.6885549426078796, Train Acc:0
# Epoch 1/3  batch 376, train Error :0.5364186763763428, Train Acc:0
# Epoch 1/3  batch 377, train Error :0.5468279719352722, Train Acc:0
# Epoch 1/3  batch 378, train Error :0.6099895238876343, Train Acc:0
# Epoch 1/3  batch 379, train Error :0.5150255560874939, Train Acc:0
# Epoch 1/3  batch 380, train Error :0.6556428074836731, Train Acc:0
# Epoch 1/3  batch 381, train Error :0.6184478998184204, Train Acc:0
# Epoch 1/3  batch 382, train Error :0.5930811762809753, Train Acc:0
# Epoch 1/3  batch 383, train Error :0.6861101388931274, Train Acc:0
# Epoch 1/3  batch 384, train Error :0.5750729441642761, Train Acc:0
# Epoch 1/3  batch 385, train Error :0.6470749378204346, Train Acc:0
# Epoch 1/3  batch 386, train Error :0.6057363152503967, Train Acc:0
# Epoch 1/3  batch 387, train Error :0.5908169150352478, Train Acc:0
# Epoch 1/3  batch 388, train Error :0.6320064067840576, Train Acc:0
# Epoch 1/3  batch 389, train Error :0.6249352693557739, Train Acc:0
# Epoch 1/3  batch 390, train Error :0.5620103478431702, Train Acc:0
# Epoch 1/3  batch 391, train Error :0.6345478296279907, Train Acc:0
# Epoch 1/3  batch 392, train Error :0.6053979396820068, Train Acc:0
# Epoch 1/3  batch 393, train Error :0.645483136177063, Train Acc:0
# Epoch 1/3  batch 394, train Error :0.6407564878463745, Train Acc:0
# Epoch 1/3  batch 395, train Error :0.5819585919380188, Train Acc:0
# Epoch 1/3  batch 396, train Error :0.5570095181465149, Train Acc:0
# Epoch 1/3  batch 397, train Error :0.6125079393386841, Train Acc:0
# Epoch 1/3  batch 398, train Error :0.4604968726634979, Train Acc:0
# Epoch 1/3  batch 399, train Error :0.5843875408172607, Train Acc:0
# Epoch 1/3  batch 400, train Error :0.5150119662284851, Train Acc:0
# Epoch 1/3  batch 401, train Error :0.5430063605308533, Train Acc:0
# Epoch 1/3  batch 402, train Error :0.699045717716217, Train Acc:0
# Epoch 1/3  batch 403, train Error :0.7791963815689087, Train Acc:0
# Epoch 1/3  batch 404, train Error :0.618857741355896, Train Acc:0
# Epoch 1/3  batch 405, train Error :0.626151442527771, Train Acc:0
# Epoch 1/3  batch 406, train Error :0.5765395164489746, Train Acc:0
# Epoch 1/3  batch 407, train Error :0.6234449148178101, Train Acc:0
# Epoch 1/3  batch 408, train Error :0.6210700273513794, Train Acc:0
# Epoch 1/3  batch 409, train Error :0.609783947467804, Train Acc:0
# Epoch 1/3  batch 410, train Error :0.5976228713989258, Train Acc:0
# Epoch 1/3  batch 411, train Error :0.5558932423591614, Train Acc:0
# Epoch 1/3  batch 412, train Error :0.6150926947593689, Train Acc:0
# Epoch 1/3  batch 413, train Error :0.6037182807922363, Train Acc:0
# Epoch 1/3  batch 414, train Error :0.5724743008613586, Train Acc:0
# Epoch 1/3  batch 415, train Error :0.6695865988731384, Train Acc:0
# Epoch 1/3  batch 416, train Error :0.6308348774909973, Train Acc:0
# Epoch 1/3  batch 417, train Error :0.6010886430740356, Train Acc:0
# Epoch 1/3  batch 418, train Error :0.5970668196678162, Train Acc:0
# Epoch 1/3  batch 419, train Error :0.6603195071220398, Train Acc:0
# Epoch 1/3  batch 420, train Error :0.5891649127006531, Train Acc:0
# Epoch 1/3  batch 421, train Error :0.5870722532272339, Train Acc:0
# Epoch 1/3  batch 422, train Error :0.6910045742988586, Train Acc:0
# Epoch 1/3  batch 423, train Error :0.7073769569396973, Train Acc:0
# Epoch 1/3  batch 424, train Error :0.5941211581230164, Train Acc:0
# Epoch 1/3  batch 425, train Error :0.6898415684700012, Train Acc:0
# Epoch 1/3  batch 426, train Error :0.6198146343231201, Train Acc:0
# Epoch 1/3  batch 427, train Error :0.6771469712257385, Train Acc:0
# Epoch 1/3  batch 428, train Error :0.5900982618331909, Train Acc:0
# Epoch 1/3  batch 429, train Error :0.5804626941680908, Train Acc:0
# Epoch 1/3  batch 430, train Error :0.6915379762649536, Train Acc:0
# Epoch 1/3  batch 431, train Error :0.5199161767959595, Train Acc:0
# Epoch 1/3  batch 432, train Error :0.6279122829437256, Train Acc:0
# Epoch 1/3  batch 433, train Error :0.6122056841850281, Train Acc:0
# Epoch 1/3  batch 434, train Error :0.6182026863098145, Train Acc:0
# Epoch 1/3  batch 435, train Error :0.6159776449203491, Train Acc:0
# Epoch 1/3  batch 436, train Error :0.6301625370979309, Train Acc:0
# Epoch 1/3  batch 437, train Error :0.6448973417282104, Train Acc:0
# Epoch 1/3  batch 438, train Error :0.6738529205322266, Train Acc:0
# Epoch 1/3  batch 439, train Error :0.6717357635498047, Train Acc:0
# Epoch 1/3  batch 440, train Error :0.6492677927017212, Train Acc:0
# Epoch 1/3  batch 441, train Error :0.6109316349029541, Train Acc:0
# Epoch 1/3  batch 442, train Error :0.570425271987915, Train Acc:0
# Epoch 1/3  batch 443, train Error :0.7062219381332397, Train Acc:0
# Epoch 1/3  batch 444, train Error :0.6974600553512573, Train Acc:0
# Epoch 1/3  batch 445, train Error :0.541481614112854, Train Acc:0
# Epoch 1/3  batch 446, train Error :0.5903962850570679, Train Acc:0
# Epoch 1/3  batch 447, train Error :0.643661618232727, Train Acc:0
# Epoch 1/3  batch 448, train Error :0.5101423263549805, Train Acc:0
# Epoch 1/3  batch 449, train Error :0.6202828884124756, Train Acc:0
# Epoch 1/3  batch 450, train Error :0.6811808943748474, Train Acc:0
# Epoch 1/3  batch 451, train Error :0.6320670247077942, Train Acc:0
# Epoch 1/3  batch 452, train Error :0.6822542548179626, Train Acc:0
# Epoch 1/3  batch 453, train Error :0.6398956775665283, Train Acc:0
# Epoch 1/3  batch 454, train Error :0.6252777576446533, Train Acc:0
# Epoch 1/3  batch 455, train Error :0.6397078633308411, Train Acc:0
# Epoch 1/3  batch 456, train Error :0.6314409971237183, Train Acc:0
# Epoch 1/3  batch 457, train Error :0.6074095368385315, Train Acc:0
# Epoch 1/3  batch 458, train Error :0.5794092416763306, Train Acc:0
# Epoch 1/3  batch 459, train Error :0.5764668583869934, Train Acc:0
# Epoch 1/3  batch 460, train Error :0.6361889243125916, Train Acc:0
# Epoch 1/3  batch 461, train Error :0.6740190386772156, Train Acc:0
# Epoch 1/3  batch 462, train Error :0.6793734431266785, Train Acc:0
# Epoch 1/3  batch 463, train Error :0.6752617955207825, Train Acc:0
# Epoch 1/3  batch 464, train Error :0.6231389045715332, Train Acc:0
# Epoch 1/3  batch 465, train Error :0.5610257983207703, Train Acc:0
# Epoch 1/3  batch 466, train Error :0.6159991025924683, Train Acc:0
# Epoch 1/3  batch 467, train Error :0.6373326778411865, Train Acc:0
# Epoch 1/3  batch 468, train Error :0.5951798558235168, Train Acc:0
# Epoch 1/3  batch 469, train Error :0.554134726524353, Train Acc:0
# Epoch 1/3  batch 470, train Error :0.5450028777122498, Train Acc:0
# Epoch 1/3  batch 471, train Error :0.7030149102210999, Train Acc:0
# Epoch 1/3  batch 472, train Error :0.5848342180252075, Train Acc:0
# Epoch 1/3  batch 473, train Error :0.6210389733314514, Train Acc:0
# Epoch 1/3  batch 474, train Error :0.7045793533325195, Train Acc:0
# Epoch 1/3  batch 475, train Error :0.7445354461669922, Train Acc:0
# Epoch 1/3  batch 476, train Error :0.5950669050216675, Train Acc:0
# Epoch 1/3  batch 477, train Error :0.6730881929397583, Train Acc:0
# Epoch 1/3  batch 478, train Error :0.6843980550765991, Train Acc:0
# Epoch 1/3  batch 479, train Error :0.6960439085960388, Train Acc:0
# Epoch 1/3  batch 480, train Error :0.5728773474693298, Train Acc:0
# Epoch 1/3  batch 481, train Error :0.6030616164207458, Train Acc:0
# Epoch 1/3  batch 482, train Error :0.6308987140655518, Train Acc:0
# Epoch 1/3  batch 483, train Error :0.6185302734375, Train Acc:0
# Epoch 1/3  batch 484, train Error :0.6336573362350464, Train Acc:0
# Epoch 1/3  batch 485, train Error :0.6581032276153564, Train Acc:0
# Epoch 1/3  batch 486, train Error :0.6825879812240601, Train Acc:0
# Epoch 1/3  batch 487, train Error :0.6337465643882751, Train Acc:0
# Epoch 1/3  batch 488, train Error :0.6381679773330688, Train Acc:0
# Epoch 1/3  batch 489, train Error :0.6544485092163086, Train Acc:0
# Epoch 1/3  batch 490, train Error :0.6212303638458252, Train Acc:0
# Epoch 1/3  batch 491, train Error :0.6285316348075867, Train Acc:0
# Epoch 1/3  batch 492, train Error :0.5988578796386719, Train Acc:0
# Epoch 1/3  batch 493, train Error :0.6197683811187744, Train Acc:0
# Epoch 1/3  batch 494, train Error :0.6136205792427063, Train Acc:0
# Epoch 1/3  batch 495, train Error :0.623515784740448, Train Acc:0
# Epoch 1/3  batch 496, train Error :0.6048508882522583, Train Acc:0
# Epoch 1/3  batch 497, train Error :0.655082106590271, Train Acc:0
# Epoch 1/3  batch 498, train Error :0.5911295413970947, Train Acc:0
# Epoch 1/3  batch 499, train Error :0.6496395468711853, Train Acc:0
# Epoch 1/3  batch 500, train Error :0.4904719293117523, Train Acc:0
# Epoch 1/3  batch 501, train Error :0.6046926379203796, Train Acc:0
# Epoch 1/3  batch 502, train Error :0.5506000518798828, Train Acc:0
# Epoch 1/3  batch 503, train Error :0.5789692997932434, Train Acc:0
# Epoch 1/3  batch 504, train Error :0.6551072001457214, Train Acc:0
# Epoch 1/3  batch 505, train Error :0.5734773874282837, Train Acc:0
# Epoch 1/3  batch 506, train Error :0.6842978596687317, Train Acc:0
# Epoch 1/3  batch 507, train Error :0.5392930507659912, Train Acc:0
# Epoch 1/3  batch 508, train Error :0.6058326363563538, Train Acc:0
# Epoch 1/3  batch 509, train Error :0.8448349237442017, Train Acc:0
# Epoch 1/3  batch 510, train Error :0.5963590741157532, Train Acc:0
# Epoch 1/3  batch 511, train Error :0.6152496933937073, Train Acc:0
# Epoch 1/3  batch 512, train Error :0.6308263540267944, Train Acc:0
# Epoch 1/3  batch 513, train Error :0.573394238948822, Train Acc:0
# Epoch 1/3  batch 514, train Error :0.5431706309318542, Train Acc:0
# Epoch 1/3  batch 515, train Error :0.6290687918663025, Train Acc:0
# Epoch 1/3  batch 516, train Error :0.5990880727767944, Train Acc:0
# Epoch 1/3  batch 517, train Error :0.5435231924057007, Train Acc:0
# Epoch 1/3  batch 518, train Error :0.6345811486244202, Train Acc:0
# Epoch 1/3  batch 519, train Error :0.58132404088974, Train Acc:0
# Epoch 1/3  batch 520, train Error :0.601576566696167, Train Acc:0
# Epoch 1/3  batch 521, train Error :0.6490748524665833, Train Acc:0
# Epoch 1/3  batch 522, train Error :0.6720092296600342, Train Acc:0
# Epoch 1/3  batch 523, train Error :0.5644130110740662, Train Acc:0
# Epoch 1/3  batch 524, train Error :0.5760035514831543, Train Acc:0
# Epoch 1/3  batch 525, train Error :0.6491819024085999, Train Acc:0
# Epoch 1/3  batch 526, train Error :0.5563350319862366, Train Acc:0
# Epoch 1/3  batch 527, train Error :0.7256269454956055, Train Acc:0
# Epoch 1/3  batch 528, train Error :0.667477548122406, Train Acc:0
# Epoch 1/3  batch 529, train Error :0.5455467700958252, Train Acc:0
# Epoch 1/3  batch 530, train Error :0.5968790650367737, Train Acc:0
# Epoch 1/3  batch 531, train Error :0.6179759502410889, Train Acc:0
# Epoch 1/3  batch 532, train Error :0.6181801557540894, Train Acc:0
# Epoch 1/3  batch 533, train Error :0.6706928610801697, Train Acc:0
# Epoch 1/3  batch 534, train Error :0.6401998400688171, Train Acc:0
# Epoch 1/3  batch 535, train Error :0.6745854616165161, Train Acc:0
# Epoch 1/3  batch 536, train Error :0.623969554901123, Train Acc:0
# Epoch 1/3  batch 537, train Error :0.5962368249893188, Train Acc:0
# Epoch 1/3  batch 538, train Error :0.5991777777671814, Train Acc:0
# Epoch 1/3  batch 539, train Error :0.5642412900924683, Train Acc:0
# Epoch 1/3  batch 540, train Error :0.6710623502731323, Train Acc:0
# Epoch 1/3  batch 541, train Error :0.663399875164032, Train Acc:0
# Epoch 1/3  batch 542, train Error :0.5786467790603638, Train Acc:0
# Epoch 1/3  batch 543, train Error :0.6250723600387573, Train Acc:0
# Epoch 1/3  batch 544, train Error :0.5744473338127136, Train Acc:0
# Epoch 1/3  batch 545, train Error :0.6171433925628662, Train Acc:0
# Epoch 1/3  batch 546, train Error :0.574871301651001, Train Acc:0
# Epoch 1/3  batch 547, train Error :0.6493632197380066, Train Acc:0
# Epoch 1/3  batch 548, train Error :0.711509644985199, Train Acc:0
# Epoch 1/3  batch 549, train Error :0.6828019618988037, Train Acc:0
# Epoch 1/3  batch 550, train Error :0.6258034706115723, Train Acc:0
# Epoch 1/3  batch 551, train Error :0.5743736624717712, Train Acc:0
# Epoch 1/3  batch 552, train Error :0.5314695239067078, Train Acc:0
# Epoch 1/3  batch 553, train Error :0.5547513961791992, Train Acc:0
# Epoch 1/3  batch 554, train Error :0.625055193901062, Train Acc:0
# Epoch 1/3  batch 555, train Error :0.5708790421485901, Train Acc:0
# Epoch 1/3  batch 556, train Error :0.6226731538772583, Train Acc:0
# Epoch 1/3  batch 557, train Error :0.5942156314849854, Train Acc:0
# Epoch 1/3  batch 558, train Error :0.662235677242279, Train Acc:0
# Epoch 1/3  batch 559, train Error :0.5246492624282837, Train Acc:0
# Epoch 1/3  batch 560, train Error :0.8205901384353638, Train Acc:0
# Epoch 1/3  batch 561, train Error :0.5723744630813599, Train Acc:0
# Epoch 1/3  batch 562, train Error :0.691251277923584, Train Acc:0
# Epoch 1/3  batch 563, train Error :0.6623465418815613, Train Acc:0
# Epoch 1/3  batch 564, train Error :0.5295296311378479, Train Acc:0
# Epoch 1/3  batch 565, train Error :0.6459081172943115, Train Acc:0
# Epoch 1/3  batch 566, train Error :0.6255652904510498, Train Acc:0
# Epoch 1/3  batch 567, train Error :0.578213632106781, Train Acc:0
# Epoch 1/3  batch 568, train Error :0.6386005878448486, Train Acc:0
# Epoch 1/3  batch 569, train Error :0.59211266040802, Train Acc:0
# Epoch 1/3  batch 570, train Error :0.5971665978431702, Train Acc:0
# Epoch 1/3  batch 571, train Error :0.6456831097602844, Train Acc:0
# Epoch 1/3  batch 572, train Error :0.5955612063407898, Train Acc:0
# Epoch 1/3  batch 573, train Error :0.6133090853691101, Train Acc:0
# Epoch 1/3  batch 574, train Error :0.6513018608093262, Train Acc:0
# Epoch 1/3  batch 575, train Error :0.632658064365387, Train Acc:0
# Epoch 1/3  batch 576, train Error :0.695671796798706, Train Acc:0
# Epoch 1/3  batch 577, train Error :0.6718612909317017, Train Acc:0
# Epoch 1/3  batch 578, train Error :0.5939384698867798, Train Acc:0
# Epoch 1/3  batch 579, train Error :0.5753480195999146, Train Acc:0
# Epoch 1/3  batch 580, train Error :0.6025778651237488, Train Acc:0
# Epoch 1/3  batch 581, train Error :0.5762962698936462, Train Acc:0
# Epoch 1/3  batch 582, train Error :0.8221412897109985, Train Acc:0
# Epoch 1/3  batch 583, train Error :0.5952169299125671, Train Acc:0
# Epoch 1/3  batch 584, train Error :0.6260777115821838, Train Acc:0
# Epoch 1/3  batch 585, train Error :0.6606111526489258, Train Acc:0
# Epoch 1/3  batch 586, train Error :0.6166636943817139, Train Acc:0
# Epoch 1/3  batch 587, train Error :0.6159058809280396, Train Acc:0
# Epoch 1/3  batch 588, train Error :0.6123406291007996, Train Acc:0
# Epoch 1/3  batch 589, train Error :0.6246267557144165, Train Acc:0
# Epoch 1/3  batch 590, train Error :0.6880822777748108, Train Acc:0
# Epoch 1/3  batch 591, train Error :0.6150941252708435, Train Acc:0
# Epoch 1/3  batch 592, train Error :0.6215512752532959, Train Acc:0
# Epoch 1/3  batch 593, train Error :0.6755354404449463, Train Acc:0
# Epoch 1/3  batch 594, train Error :0.5956446528434753, Train Acc:0
# Epoch 1/3  batch 595, train Error :0.6044262051582336, Train Acc:0
# Epoch 1/3  batch 596, train Error :0.6523700952529907, Train Acc:0
# Epoch 1/3  batch 597, train Error :0.5519077777862549, Train Acc:0
# Epoch 1/3  batch 598, train Error :0.6526668667793274, Train Acc:0
# Epoch 1/3  batch 599, train Error :0.5832824110984802, Train Acc:0
# Epoch 1/3  batch 600, train Error :0.6497957110404968, Train Acc:0
# Epoch 1/3  batch 601, train Error :0.6531336903572083, Train Acc:0
# Epoch 1/3  batch 602, train Error :0.6356325149536133, Train Acc:0
# Epoch 1/3  batch 603, train Error :0.588928759098053, Train Acc:0
# Epoch 1/3  batch 604, train Error :0.6203432679176331, Train Acc:0
# Epoch 1/3  batch 605, train Error :0.6792308688163757, Train Acc:0
# Epoch 1/3  batch 606, train Error :0.5465542674064636, Train Acc:0
# Epoch 1/3  batch 607, train Error :0.5344577431678772, Train Acc:0
# Epoch 1/3  batch 608, train Error :0.6090149283409119, Train Acc:0
# Epoch 1/3  batch 609, train Error :0.6331083178520203, Train Acc:0
# Epoch 1/3  batch 610, train Error :0.6093114018440247, Train Acc:0
# Epoch 1/3  batch 611, train Error :0.6623551249504089, Train Acc:0
# Epoch 1/3  batch 612, train Error :0.5891798138618469, Train Acc:0
# Epoch 1/3  batch 613, train Error :0.5863797068595886, Train Acc:0
# Epoch 1/3  batch 614, train Error :0.5447105765342712, Train Acc:0
# Epoch 1/3  batch 615, train Error :0.6145750880241394, Train Acc:0
# Epoch 1/3  batch 616, train Error :0.5728192329406738, Train Acc:0
# Epoch 1/3  batch 617, train Error :0.5434419512748718, Train Acc:0
# Epoch 1/3  batch 618, train Error :0.6333765983581543, Train Acc:0
# Epoch 1/3  batch 619, train Error :0.6161723136901855, Train Acc:0
# Epoch 1/3  batch 620, train Error :0.5897520184516907, Train Acc:0
# Epoch 1/3  batch 621, train Error :0.501127302646637, Train Acc:0
# Epoch 1/3  batch 622, train Error :0.5224227905273438, Train Acc:0
# Epoch 1/3  batch 623, train Error :0.5637486577033997, Train Acc:0
# Epoch 1/3  batch 624, train Error :0.592385470867157, Train Acc:0
# Epoch 1/3  batch 625, train Error :0.6017144322395325, Train Acc:0
# Epoch 1/3  batch 626, train Error :0.6171565651893616, Train Acc:0
# Epoch 1/3  batch 627, train Error :0.5818796157836914, Train Acc:0
# Epoch 1/3  batch 628, train Error :0.4794827103614807, Train Acc:0
# Epoch 1/3  batch 629, train Error :0.5295770764350891, Train Acc:0
# Epoch 1/3  batch 630, train Error :0.5104730725288391, Train Acc:0
# Epoch 1/3  batch 631, train Error :0.6995202302932739, Train Acc:0
# Epoch 1/3  batch 632, train Error :0.5332944989204407, Train Acc:0
# Epoch 1/3  batch 633, train Error :0.6331362724304199, Train Acc:0
# Epoch 1/3  batch 634, train Error :0.5285829901695251, Train Acc:0
# Epoch 1/3  batch 635, train Error :0.504857063293457, Train Acc:0
# Epoch 1/3  batch 636, train Error :0.6780701279640198, Train Acc:0
# Epoch 1/3  batch 637, train Error :0.5575441122055054, Train Acc:0
# Epoch 1/3  batch 638, train Error :0.5569548606872559, Train Acc:0
# Epoch 1/3  batch 639, train Error :0.6456498503684998, Train Acc:0
# Epoch 1/3  batch 640, train Error :0.6172885894775391, Train Acc:0
# Epoch 1/3  batch 641, train Error :0.5908637642860413, Train Acc:0
# Epoch 1/3  batch 642, train Error :0.5793272256851196, Train Acc:0
# Epoch 1/3  batch 643, train Error :0.572304904460907, Train Acc:0
# Epoch 1/3  batch 644, train Error :0.5783843994140625, Train Acc:0
# Epoch 1/3  batch 645, train Error :0.6260845065116882, Train Acc:0
# Epoch 1/3  batch 646, train Error :0.6191258430480957, Train Acc:0
# Epoch 1/3  batch 647, train Error :0.6183297634124756, Train Acc:0
# Epoch 1/3  batch 648, train Error :0.6518529653549194, Train Acc:0
# Epoch 1/3  batch 649, train Error :0.5357522964477539, Train Acc:0
# Epoch 1/3  batch 650, train Error :0.5730113983154297, Train Acc:0
# Epoch 1/3  batch 651, train Error :0.49457457661628723, Train Acc:0
# Epoch 1/3  batch 652, train Error :0.6787480115890503, Train Acc:0
# Epoch 1/3  batch 653, train Error :0.603771984577179, Train Acc:0
# Epoch 1/3  batch 654, train Error :0.618941068649292, Train Acc:0
# Epoch 1/3  batch 655, train Error :0.6163755059242249, Train Acc:0
# Epoch 1/3  batch 656, train Error :0.5878596901893616, Train Acc:0
# Epoch 1/3  batch 657, train Error :0.5002242922782898, Train Acc:0
# Epoch 1/3  batch 658, train Error :0.6206276416778564, Train Acc:0
# Epoch 1/3  batch 659, train Error :0.6252111792564392, Train Acc:0
# Epoch 1/3  batch 660, train Error :0.5214704275131226, Train Acc:0
# Epoch 1/3  batch 661, train Error :0.6473833322525024, Train Acc:0
# Epoch 1/3  batch 662, train Error :0.5812619924545288, Train Acc:0
# Epoch 1/3  batch 663, train Error :0.5686391592025757, Train Acc:0
# Epoch 1/3  batch 664, train Error :0.5775467753410339, Train Acc:0
# Epoch 1/3  batch 665, train Error :0.6505950093269348, Train Acc:0
# Epoch 1/3  batch 666, train Error :0.5919681787490845, Train Acc:0
# Epoch 1/3  batch 667, train Error :0.6762014627456665, Train Acc:0
# Epoch 1/3  batch 668, train Error :0.5918797850608826, Train Acc:0
# Epoch 1/3  batch 669, train Error :0.5904601216316223, Train Acc:0
# Epoch 1/3  batch 670, train Error :0.5576948523521423, Train Acc:0
# Epoch 1/3  batch 671, train Error :0.6491724252700806, Train Acc:0
# Epoch 1/3  batch 672, train Error :0.6008026003837585, Train Acc:0
# Epoch 1/3  batch 673, train Error :0.5263087153434753, Train Acc:0
# Epoch 1/3  batch 674, train Error :0.5706000924110413, Train Acc:0
# Epoch 1/3  batch 675, train Error :0.5402481555938721, Train Acc:0
# Epoch 1/3  batch 676, train Error :0.7034443020820618, Train Acc:0
# Epoch 1/3  batch 677, train Error :0.6157702803611755, Train Acc:0
# Epoch 1/3  batch 678, train Error :0.4948273301124573, Train Acc:0
# Epoch 1/3  batch 679, train Error :0.5881770253181458, Train Acc:0
# Epoch 1/3  batch 680, train Error :0.6022615432739258, Train Acc:0
# Epoch 1/3  batch 681, train Error :0.5536360740661621, Train Acc:0
# Epoch 1/3  batch 682, train Error :0.5177721381187439, Train Acc:0
# Epoch 1/3  batch 683, train Error :0.544721245765686, Train Acc:0
# Epoch 1/3  batch 684, train Error :0.580561101436615, Train Acc:0
# Epoch 1/3  batch 685, train Error :0.5844289660453796, Train Acc:0
# Epoch 1/3  batch 686, train Error :0.5728066563606262, Train Acc:0
# Epoch 1/3  batch 687, train Error :0.532075047492981, Train Acc:0
# Epoch 1/3  batch 688, train Error :0.6326199769973755, Train Acc:0
# Epoch 1/3  batch 689, train Error :0.5247376561164856, Train Acc:0
# Epoch 1/3  batch 690, train Error :0.5564236640930176, Train Acc:0
# Epoch 1/3  batch 691, train Error :0.6035832762718201, Train Acc:0
# Epoch 1/3  batch 692, train Error :0.5367018580436707, Train Acc:0
# Epoch 1/3  batch 693, train Error :0.5390499234199524, Train Acc:0
# Epoch 1/3  batch 694, train Error :0.5907877683639526, Train Acc:0
# Epoch 1/3  batch 695, train Error :0.7072262167930603, Train Acc:0
# Epoch 1/3  batch 696, train Error :0.604692816734314, Train Acc:0
# Epoch 1/3  batch 697, train Error :0.638675332069397, Train Acc:0
# Epoch 1/3  batch 698, train Error :0.6649291515350342, Train Acc:0
# Epoch 1/3  batch 699, train Error :0.6459596753120422, Train Acc:0
# Epoch 1/3  batch 700, train Error :0.5625410676002502, Train Acc:0
# Epoch 1/3  batch 701, train Error :0.623213529586792, Train Acc:0
# Epoch 1/3  batch 702, train Error :0.5879491567611694, Train Acc:0
# Epoch 1/3  batch 703, train Error :0.5929161310195923, Train Acc:0
# Epoch 1/3  batch 704, train Error :0.5532305836677551, Train Acc:0
# Epoch 1/3  batch 705, train Error :0.5744976997375488, Train Acc:0
# Epoch 1/3  batch 706, train Error :0.5727704763412476, Train Acc:0
# Epoch 1/3  batch 707, train Error :0.7123332023620605, Train Acc:0
# Epoch 1/3  batch 708, train Error :0.5690281987190247, Train Acc:0
# Epoch 1/3  batch 709, train Error :0.609569787979126, Train Acc:0
# Epoch 1/3  batch 710, train Error :0.5647631883621216, Train Acc:0
# Epoch 1/3  batch 711, train Error :0.6193113923072815, Train Acc:0
# Epoch 1/3  batch 712, train Error :0.5804370045661926, Train Acc:0
# Epoch 1/3  batch 713, train Error :0.5957136154174805, Train Acc:0
# Epoch 1/3  batch 714, train Error :0.5608062744140625, Train Acc:0
# Epoch 1/3  batch 715, train Error :0.6311001777648926, Train Acc:0
# Epoch 1/3  batch 716, train Error :0.5767286419868469, Train Acc:0
# Epoch 1/3  batch 717, train Error :0.6887902021408081, Train Acc:0
# Epoch 1/3  batch 718, train Error :0.6468225121498108, Train Acc:0
# Epoch 1/3  batch 719, train Error :0.5992736220359802, Train Acc:0
# ...
# Epoch 3/3  batch 498, train Error :0.4794279932975769, Train Acc:0
# Epoch 3/3  batch 499, train Error :0.4637320041656494, Train Acc:0
# Epoch 3/3  batch 500, train Error :0.5822191834449768, Train Acc:0
# Epoch 3/3  batch 501, train Error :0.5162702202796936, Train Acc:0
# Epoch 3/3  batch 502, train Error :0.45110660791397095, Train Acc:0
# Epoch 3/3  batch 503, train Error :0.5411239266395569, Train Acc:0
# Epoch 3/3  batch 504, train Error :0.43466895818710327, Train Acc:0
# Epoch 3/3  batch 505, train Error :0.5044362545013428, Train Acc:0
# Epoch 3/3  batch 506, train Error :0.5418346524238586, Train Acc:0
# Epoch 3/3  batch 507, train Error :0.4476037621498108, Train Acc:0
# Epoch 3/3  batch 508, train Error :0.5360084772109985, Train Acc:0
# Epoch 3/3  batch 509, train Error :0.6019704341888428, Train Acc:0
# Epoch 3/3  batch 510, train Error :0.4610597789287567, Train Acc:0
# Epoch 3/3  batch 511, train Error :0.4945611357688904, Train Acc:0
# Epoch 3/3  batch 512, train Error :0.5042404532432556, Train Acc:0
# Epoch 3/3  batch 513, train Error :0.493145227432251, Train Acc:0
# Epoch 3/3  batch 514, train Error :0.48391446471214294, Train Acc:0
# Epoch 3/3  batch 515, train Error :0.6078067421913147, Train Acc:0
# Epoch 3/3  batch 516, train Error :0.5978050231933594, Train Acc:0
# Epoch 3/3  batch 517, train Error :0.738271176815033, Train Acc:0
# Epoch 3/3  batch 518, train Error :0.562969446182251, Train Acc:0
# Epoch 3/3  batch 519, train Error :0.5266940593719482, Train Acc:0
# Epoch 3/3  batch 520, train Error :0.4773431122303009, Train Acc:0
# Epoch 3/3  batch 521, train Error :0.5942959785461426, Train Acc:0
# Epoch 3/3  batch 522, train Error :0.6257771849632263, Train Acc:0
# Epoch 3/3  batch 523, train Error :0.5261534452438354, Train Acc:0
# Epoch 3/3  batch 524, train Error :0.5509855151176453, Train Acc:0
# Epoch 3/3  batch 525, train Error :0.6465796828269958, Train Acc:0
# Epoch 3/3  batch 526, train Error :0.5510314702987671, Train Acc:0
# Epoch 3/3  batch 527, train Error :0.49396759271621704, Train Acc:0
# Epoch 3/3  batch 528, train Error :0.5578871369361877, Train Acc:0
# Epoch 3/3  batch 529, train Error :0.49067750573158264, Train Acc:0
# Epoch 3/3  batch 530, train Error :0.473940908908844, Train Acc:0
# Epoch 3/3  batch 531, train Error :0.47924137115478516, Train Acc:0
# Epoch 3/3  batch 532, train Error :0.5459293127059937, Train Acc:0
# Epoch 3/3  batch 533, train Error :0.6035441160202026, Train Acc:0
# Epoch 3/3  batch 534, train Error :0.5113121867179871, Train Acc:0
# Epoch 3/3  batch 535, train Error :0.5752235054969788, Train Acc:0
# Epoch 3/3  batch 536, train Error :0.5351110696792603, Train Acc:0
# Epoch 3/3  batch 537, train Error :0.6221759915351868, Train Acc:0
# Epoch 3/3  batch 538, train Error :0.6106581687927246, Train Acc:0
# Epoch 3/3  batch 539, train Error :0.5038753151893616, Train Acc:0
# Epoch 3/3  batch 540, train Error :0.4576253890991211, Train Acc:0
# Epoch 3/3  batch 541, train Error :0.3739812672138214, Train Acc:0
# Epoch 3/3  batch 542, train Error :0.49438509345054626, Train Acc:0
# Epoch 3/3  batch 543, train Error :0.51309734582901, Train Acc:0
# Epoch 3/3  batch 544, train Error :0.5152441263198853, Train Acc:0
# Epoch 3/3  batch 545, train Error :0.5119274258613586, Train Acc:0
# Epoch 3/3  batch 546, train Error :0.5796696543693542, Train Acc:0
# Epoch 3/3  batch 547, train Error :0.5958858132362366, Train Acc:0
# Epoch 3/3  batch 548, train Error :0.48838841915130615, Train Acc:0
# Epoch 3/3  batch 549, train Error :0.480275422334671, Train Acc:0
# Epoch 3/3  batch 550, train Error :0.49578604102134705, Train Acc:0
# Epoch 3/3  batch 551, train Error :0.47844401001930237, Train Acc:0
# Epoch 3/3  batch 552, train Error :0.4806511402130127, Train Acc:0
# Epoch 3/3  batch 553, train Error :0.46396535634994507, Train Acc:0
# Epoch 3/3  batch 554, train Error :0.48343783617019653, Train Acc:0
# Epoch 3/3  batch 555, train Error :0.4358730614185333, Train Acc:0
# Epoch 3/3  batch 556, train Error :0.5605220794677734, Train Acc:0
# Epoch 3/3  batch 557, train Error :0.5008507966995239, Train Acc:0
# Epoch 3/3  batch 558, train Error :0.5201659202575684, Train Acc:0
# Epoch 3/3  batch 559, train Error :0.5371023416519165, Train Acc:0
# Epoch 3/3  batch 560, train Error :0.47784286737442017, Train Acc:0
# Epoch 3/3  batch 561, train Error :0.31794273853302, Train Acc:0
# Epoch 3/3  batch 562, train Error :0.35538941621780396, Train Acc:0
# Epoch 3/3  batch 563, train Error :0.3929106593132019, Train Acc:0
# Epoch 3/3  batch 564, train Error :0.5951414704322815, Train Acc:0
# Epoch 3/3  batch 565, train Error :0.5805572271347046, Train Acc:0
# Epoch 3/3  batch 566, train Error :0.48588496446609497, Train Acc:0
# Epoch 3/3  batch 567, train Error :0.41314810514450073, Train Acc:0
# Epoch 3/3  batch 568, train Error :0.6442047357559204, Train Acc:0
# Epoch 3/3  batch 569, train Error :0.5920912027359009, Train Acc:0
# Epoch 3/3  batch 570, train Error :0.5127650499343872, Train Acc:0
# Epoch 3/3  batch 571, train Error :0.5603071451187134, Train Acc:0
# Epoch 3/3  batch 572, train Error :0.7189069390296936, Train Acc:0
# Epoch 3/3  batch 573, train Error :0.5574860572814941, Train Acc:0
# Epoch 3/3  batch 574, train Error :0.4094363749027252, Train Acc:0
# Epoch 3/3  batch 575, train Error :0.4364142119884491, Train Acc:0
# Epoch 3/3  batch 576, train Error :0.5473224520683289, Train Acc:0
# Epoch 3/3  batch 577, train Error :0.5420530438423157, Train Acc:0
# Epoch 3/3  batch 578, train Error :0.5896828174591064, Train Acc:0
# Epoch 3/3  batch 579, train Error :0.5340080261230469, Train Acc:0
# Epoch 3/3  batch 580, train Error :0.49588388204574585, Train Acc:0
# Epoch 3/3  batch 581, train Error :0.5233650803565979, Train Acc:0
# Epoch 3/3  batch 582, train Error :0.569746732711792, Train Acc:0
# Epoch 3/3  batch 583, train Error :0.5106390118598938, Train Acc:0
# Epoch 3/3  batch 584, train Error :0.5893226265907288, Train Acc:0
# Epoch 3/3  batch 585, train Error :0.5123390555381775, Train Acc:0
# Epoch 3/3  batch 586, train Error :0.5355241894721985, Train Acc:0
# Epoch 3/3  batch 587, train Error :0.4824489653110504, Train Acc:0
# Epoch 3/3  batch 588, train Error :0.5859267115592957, Train Acc:0
# Epoch 3/3  batch 589, train Error :0.5435606837272644, Train Acc:0
# Epoch 3/3  batch 590, train Error :0.5292426943778992, Train Acc:0
# Epoch 3/3  batch 591, train Error :0.5212430953979492, Train Acc:0
# Epoch 3/3  batch 592, train Error :0.5989125370979309, Train Acc:0
# Epoch 3/3  batch 593, train Error :0.45102494955062866, Train Acc:0
# Epoch 3/3  batch 594, train Error :0.5548735857009888, Train Acc:0
# Epoch 3/3  batch 595, train Error :0.5254856944084167, Train Acc:0
# Epoch 3/3  batch 596, train Error :0.5219293236732483, Train Acc:0
# Epoch 3/3  batch 597, train Error :0.5470077395439148, Train Acc:0
# Epoch 3/3  batch 598, train Error :0.4877091944217682, Train Acc:0
# Epoch 3/3  batch 599, train Error :0.49197494983673096, Train Acc:0
# Epoch 3/3  batch 600, train Error :0.45421668887138367, Train Acc:0
# Epoch 3/3  batch 601, train Error :0.44336190819740295, Train Acc:0
# Epoch 3/3  batch 602, train Error :0.6546007990837097, Train Acc:0
# Epoch 3/3  batch 603, train Error :0.5176001191139221, Train Acc:0
# Epoch 3/3  batch 604, train Error :0.5292131304740906, Train Acc:0
# Epoch 3/3  batch 605, train Error :0.4966451823711395, Train Acc:0
# Epoch 3/3  batch 606, train Error :0.7340043783187866, Train Acc:0
# Epoch 3/3  batch 607, train Error :0.556762158870697, Train Acc:0
# Epoch 3/3  batch 608, train Error :0.48645299673080444, Train Acc:0
# Epoch 3/3  batch 609, train Error :0.6625074148178101, Train Acc:0
# Epoch 3/3  batch 610, train Error :0.44488027691841125, Train Acc:0
# Epoch 3/3  batch 611, train Error :0.44578254222869873, Train Acc:0
# Epoch 3/3  batch 612, train Error :0.4761646091938019, Train Acc:0
# Epoch 3/3  batch 613, train Error :0.4802832007408142, Train Acc:0
# Epoch 3/3  batch 614, train Error :0.5244999527931213, Train Acc:0
# Epoch 3/3  batch 615, train Error :0.4814399182796478, Train Acc:0
# Epoch 3/3  batch 616, train Error :0.46278154850006104, Train Acc:0
# Epoch 3/3  batch 617, train Error :0.41622188687324524, Train Acc:0
# Epoch 3/3  batch 618, train Error :0.5390904545783997, Train Acc:0
# Epoch 3/3  batch 619, train Error :0.5286090970039368, Train Acc:0
# Epoch 3/3  batch 620, train Error :0.38878166675567627, Train Acc:0
# Epoch 3/3  batch 621, train Error :0.4960060119628906, Train Acc:0
# Epoch 3/3  batch 622, train Error :0.6225399374961853, Train Acc:0
# Epoch 3/3  batch 623, train Error :0.4746808707714081, Train Acc:0
# Epoch 3/3  batch 624, train Error :0.4391959011554718, Train Acc:0
# Epoch 3/3  batch 625, train Error :0.40718430280685425, Train Acc:0
# Epoch 3/3  batch 626, train Error :0.49257802963256836, Train Acc:0
# Epoch 3/3  batch 627, train Error :0.5212648510932922, Train Acc:0
# Epoch 3/3  batch 628, train Error :0.5717574954032898, Train Acc:0
# Epoch 3/3  batch 629, train Error :0.6146059036254883, Train Acc:0
# Epoch 3/3  batch 630, train Error :0.5299921035766602, Train Acc:0
# Epoch 3/3  batch 631, train Error :0.436881959438324, Train Acc:0
# Epoch 3/3  batch 632, train Error :0.6837183237075806, Train Acc:0
# Epoch 3/3  batch 633, train Error :0.4962122142314911, Train Acc:0
# Epoch 3/3  batch 634, train Error :0.5065884590148926, Train Acc:0
# Epoch 3/3  batch 635, train Error :0.4829671084880829, Train Acc:0
# Epoch 3/3  batch 636, train Error :0.5496392846107483, Train Acc:0
# Epoch 3/3  batch 637, train Error :0.6180816888809204, Train Acc:0
# Epoch 3/3  batch 638, train Error :0.46595636010169983, Train Acc:0
# Epoch 3/3  batch 639, train Error :0.4360147714614868, Train Acc:0
# Epoch 3/3  batch 640, train Error :0.5833470225334167, Train Acc:0
# Epoch 3/3  batch 641, train Error :0.5455237627029419, Train Acc:0
# Epoch 3/3  batch 642, train Error :0.5217594504356384, Train Acc:0
# Epoch 3/3  batch 643, train Error :0.4966650903224945, Train Acc:0
# Epoch 3/3  batch 644, train Error :0.5370798110961914, Train Acc:0
# Epoch 3/3  batch 645, train Error :0.6806602478027344, Train Acc:0
# Epoch 3/3  batch 646, train Error :0.5437472462654114, Train Acc:0
# Epoch 3/3  batch 647, train Error :0.6814759969711304, Train Acc:0
# Epoch 3/3  batch 648, train Error :0.5537220239639282, Train Acc:0
# Epoch 3/3  batch 649, train Error :0.5370299220085144, Train Acc:0
# Epoch 3/3  batch 650, train Error :0.5649197697639465, Train Acc:0
# Epoch 3/3  batch 651, train Error :0.6308691501617432, Train Acc:0
# Epoch 3/3  batch 652, train Error :0.5748314261436462, Train Acc:0
# Epoch 3/3  batch 653, train Error :0.4645218849182129, Train Acc:0
# Epoch 3/3  batch 654, train Error :0.5575279593467712, Train Acc:0
# Epoch 3/3  batch 655, train Error :0.4651258885860443, Train Acc:0
# Epoch 3/3  batch 656, train Error :0.48874789476394653, Train Acc:0
# Epoch 3/3  batch 657, train Error :0.5387965440750122, Train Acc:0
# Epoch 3/3  batch 658, train Error :0.6436007022857666, Train Acc:0
# Epoch 3/3  batch 659, train Error :0.5737773776054382, Train Acc:0
# Epoch 3/3  batch 660, train Error :0.485024631023407, Train Acc:0
# Epoch 3/3  batch 661, train Error :0.5498481392860413, Train Acc:0
# Epoch 3/3  batch 662, train Error :0.5564528703689575, Train Acc:0
# Epoch 3/3  batch 663, train Error :0.6088880300521851, Train Acc:0
# Epoch 3/3  batch 664, train Error :0.5751493573188782, Train Acc:0
# Epoch 3/3  batch 665, train Error :0.6047960519790649, Train Acc:0
# Epoch 3/3  batch 666, train Error :0.4949738383293152, Train Acc:0
# Epoch 3/3  batch 667, train Error :0.5190799236297607, Train Acc:0
# Epoch 3/3  batch 668, train Error :0.4995644986629486, Train Acc:0
# Epoch 3/3  batch 669, train Error :0.5866404175758362, Train Acc:0
# Epoch 3/3  batch 670, train Error :0.47518351674079895, Train Acc:0
# Epoch 3/3  batch 671, train Error :0.5478705167770386, Train Acc:0
# Epoch 3/3  batch 672, train Error :0.4465997517108917, Train Acc:0
# Epoch 3/3  batch 673, train Error :0.4686683118343353, Train Acc:0
# Epoch 3/3  batch 674, train Error :0.43206167221069336, Train Acc:0
# Epoch 3/3  batch 675, train Error :0.5305725336074829, Train Acc:0
# Epoch 3/3  batch 676, train Error :0.6438600420951843, Train Acc:0
# Epoch 3/3  batch 677, train Error :0.49482449889183044, Train Acc:0
# Epoch 3/3  batch 678, train Error :0.5270541310310364, Train Acc:0
# Epoch 3/3  batch 679, train Error :0.5044044256210327, Train Acc:0
# Epoch 3/3  batch 680, train Error :0.5555422306060791, Train Acc:0
# Epoch 3/3  batch 681, train Error :0.6545138359069824, Train Acc:0
# Epoch 3/3  batch 682, train Error :0.5229211449623108, Train Acc:0
# Epoch 3/3  batch 683, train Error :0.50396728515625, Train Acc:0
# Epoch 3/3  batch 684, train Error :0.5088340044021606, Train Acc:0
# Epoch 3/3  batch 685, train Error :0.4560399055480957, Train Acc:0
# Epoch 3/3  batch 686, train Error :0.5045682787895203, Train Acc:0
# Epoch 3/3  batch 687, train Error :0.4829427897930145, Train Acc:0
# Epoch 3/3  batch 688, train Error :0.6296396255493164, Train Acc:0
# Epoch 3/3  batch 689, train Error :0.5713521838188171, Train Acc:0
# Epoch 3/3  batch 690, train Error :0.4985940754413605, Train Acc:0
# Epoch 3/3  batch 691, train Error :0.4922510087490082, Train Acc:0
# Epoch 3/3  batch 692, train Error :0.5559004545211792, Train Acc:0
# Epoch 3/3  batch 693, train Error :0.5582935810089111, Train Acc:0
# Epoch 3/3  batch 694, train Error :0.5628491640090942, Train Acc:0
# Epoch 3/3  batch 695, train Error :0.6123177409172058, Train Acc:0
# Epoch 3/3  batch 696, train Error :0.5329776406288147, Train Acc:0
# Epoch 3/3  batch 697, train Error :0.5158061385154724, Train Acc:0
# Epoch 3/3  batch 698, train Error :0.519199013710022, Train Acc:0
# Epoch 3/3  batch 699, train Error :0.46183693408966064, Train Acc:0
# Epoch 3/3  batch 700, train Error :0.4553222358226776, Train Acc:0
# Epoch 3/3  batch 701, train Error :0.42191198468208313, Train Acc:0
# Epoch 3/3  batch 702, train Error :0.6288216710090637, Train Acc:0
# Epoch 3/3  batch 703, train Error :0.5334178805351257, Train Acc:0
# Epoch 3/3  batch 704, train Error :0.536263108253479, Train Acc:0
# Epoch 3/3  batch 705, train Error :0.579908549785614, Train Acc:0
# Epoch 3/3  batch 706, train Error :0.5802609920501709, Train Acc:0
# Epoch 3/3  batch 707, train Error :0.525337278842926, Train Acc:0
# Epoch 3/3  batch 708, train Error :0.49109625816345215, Train Acc:0
# Epoch 3/3  batch 709, train Error :0.5006439089775085, Train Acc:0
# Epoch 3/3  batch 710, train Error :0.41889309883117676, Train Acc:0
# Epoch 3/3  batch 711, train Error :0.6146048307418823, Train Acc:0
# Epoch 3/3  batch 712, train Error :0.5079848766326904, Train Acc:0
# Epoch 3/3  batch 713, train Error :0.5190912485122681, Train Acc:0
# Epoch 3/3  batch 714, train Error :0.541670560836792, Train Acc:0
# Epoch 3/3  batch 715, train Error :0.6018136143684387, Train Acc:0
# Epoch 3/3  batch 716, train Error :0.624500036239624, Train Acc:0
# Epoch 3/3  batch 717, train Error :0.4205356240272522, Train Acc:0
# Epoch 3/3  batch 718, train Error :0.510229766368866, Train Acc:0
# Epoch 3/3  batch 719, train Error :0.6328259110450745, Train Acc:0
# Epoch 3/3  batch 720, train Error :0.4940946698188782, Train Acc:0
# Epoch 3/3  batch 721, train Error :0.4986376166343689, Train Acc:0
# Epoch 3/3  batch 722, train Error :0.5066326856613159, Train Acc:0
# Epoch 3/3  batch 723, train Error :0.506126344203949, Train Acc:0
# Epoch 3/3  batch 724, train Error :0.5062626600265503, Train Acc:0
# Epoch 3/3  batch 725, train Error :0.488768994808197, Train Acc:0
# Epoch 3/3  batch 726, train Error :0.47632110118865967, Train Acc:0
# Epoch 3/3  batch 727, train Error :0.4581905007362366, Train Acc:0
# Epoch 3/3  batch 728, train Error :0.4537504017353058, Train Acc:0
# Epoch 3/3  batch 729, train Error :0.5151751041412354, Train Acc:0
# Epoch 3/3  batch 730, train Error :0.5820909142494202, Train Acc:0
# Epoch 3/3  batch 731, train Error :0.5454739928245544, Train Acc:0
# Epoch 3/3  batch 732, train Error :0.42377805709838867, Train Acc:0
# Epoch 3/3  batch 733, train Error :0.5109768509864807, Train Acc:0
# Epoch 3/3  batch 734, train Error :0.3750092387199402, Train Acc:0
# Epoch 3/3  batch 735, train Error :0.4719243049621582, Train Acc:0
